# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
# %matplotlib inline

# %%
df = pd.read_csv('./input/train.csv')

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
#                   ...
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# KitchenQual       object
# TotRmsAbvGrd       int64
# Functional        object
# Fireplaces         int64
# ...

# %%
#欠損値のある列の欠損値数を表示
df_count = len(df) - df.count()
df_count[df_count != 0]
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
df_new = df.drop(['Alley', 'PoolQC', 'Fence', 'MiscFeature', 'FireplaceQu', 'Id'], axis=1)

# %%
df_new.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0          60       RL         65.0     8450   Pave      Reg         Lvl
# 1          20       RL         80.0     9600   Pave      Reg         Lvl
# 2          60       RL         68.0    11250   Pave      IR1         Lvl
# 3          70       RL         60.0     9550   Pave      IR1         Lvl
# 4          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope    ...    EnclosedPorch 3SsnPorch ScreenPorch  \
# 0    AllPub    Inside       Gtl    ...                0         0           0
# 1    AllPub       FR2       Gtl    ...                0         0           0
# 2    AllPub    Inside       Gtl    ...                0         0           0
# 3    AllPub    Corner       Gtl    ...              272         0           0
# 4    AllPub       FR2       Gtl    ...                0         0           0
#
# ...

# %%
df_new.hist(figsize=(15, 15));

# %%
train_ID = df['Id']

# %%
df_new.isnull().sum()[df_new.isnull().sum() != 0]
# Out:
# LotFrontage     259
# MasVnrType        8
# MasVnrArea        8
# BsmtQual         37
# BsmtCond         37
# BsmtExposure     38
# BsmtFinType1     37
# BsmtFinType2     38
# Electrical        1
# GarageType       81
# GarageYrBlt      81
# GarageFinish     81
# GarageQual       81
# GarageCond       81
# dtype: int64

# %%
df_new2 = df_new.dropna()

# %%
df_new2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1094 entries, 0 to 1459
# Data columns (total 75 columns):
# MSSubClass       1094 non-null int64
# MSZoning         1094 non-null object
# LotFrontage      1094 non-null float64
# LotArea          1094 non-null int64
# Street           1094 non-null object
# LotShape         1094 non-null object
# LandContour      1094 non-null object
# Utilities        1094 non-null object
# LotConfig        1094 non-null object
# LandSlope        1094 non-null object
# Neighborhood     1094 non-null object
# Condition1       1094 non-null object
# Condition2       1094 non-null object
# BldgType         1094 non-null object
# HouseStyle       1094 non-null object
# OverallQual      1094 non-null int64
# OverallCond      1094 non-null int64
# YearBuilt        1094 non-null int64
# YearRemodAdd     1094 non-null int64
# RoofStyle        1094 non-null object
# RoofMatl         1094 non-null object
# Exterior1st      1094 non-null object
# ...

# %%
# !pip install category_encoders

# %%
import category_encoders as ce
y_train = df_new2.iloc[:, -1]
X_train = df_new2.iloc[:, :-1]
cols = X_train.select_dtypes(include='object').columns.tolist()
ohe = ce.OneHotEncoder(cols=cols,handle_unknown='impute', drop_invariant=False, use_cat_names=True)
type(cols)
# Out:
# list

# %%
X_train.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0          60       RL         65.0     8450   Pave      Reg         Lvl
# 1          20       RL         80.0     9600   Pave      Reg         Lvl
# 2          60       RL         68.0    11250   Pave      IR1         Lvl
# 3          70       RL         60.0     9550   Pave      IR1         Lvl
# 4          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope      ...      OpenPorchSF EnclosedPorch  \
# 0    AllPub    Inside       Gtl      ...               61             0
# 1    AllPub       FR2       Gtl      ...                0             0
# 2    AllPub    Inside       Gtl      ...               42             0
# 3    AllPub    Corner       Gtl      ...               35           272
# 4    AllPub       FR2       Gtl      ...               84             0
#
#   3SsnPorch ScreenPorch PoolArea  MiscVal  MoSold  YrSold  SaleType  \
# ...

# %%
ohe.fit(X_train)
X_train = ohe.transform(X_train)
X_train.head()
# Out:
#    MSSubClass  MSZoning_RL  MSZoning_RM  MSZoning_C (all)  MSZoning_FV  \
# 0          60            1            0                 0            0
# 1          20            1            0                 0            0
# 2          60            1            0                 0            0
# 3          70            1            0                 0            0
# 4          60            1            0                 0            0
#
#    MSZoning_RH  LotFrontage  LotArea  Street_Pave  Street_Grvl  \
# 0            0         65.0     8450            1            0
# 1            0         80.0     9600            1            0
# 2            0         68.0    11250            1            0
# 3            0         60.0     9550            1            0
# 4            0         84.0    14260            1            0
#
#            ...            SaleType_ConLw  SaleType_Con  SaleType_ConLD  \
# 0          ...                         0             0               0
# ...

# %%
# y_train = df_cat.iloc[:, -1]
# X_train = df_cat.iloc[:, :-1]

# %%
sns.distplot(y_train)
# Out:
# C:\Users\Toshiya_2\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
y_train = np.log(y_train)

# %%
sns.distplot(y_train)
# Out:
# C:\Users\Toshiya_2\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
# !pip install xgboost

# %%
# XGBoost
import xgboost as xgb
from sklearn.model_selection import GridSearchCV

print("Parameter optimization")
xgb_model = xgb.XGBRegressor()
reg_xgb = GridSearchCV(xgb_model,
                   {'max_depth': [2,4,6],
                    'n_estimators': [50,100,200]}, verbose=1)
reg_xgb.fit(X_train, y_train)
# Out:
# Parameter optimization
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [01:00:15] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\Toshiya_2\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [01:00:15] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:00:16] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ...

# %%
df_test = pd.read_csv('./input/test.csv')

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
# Id               1459 non-null int64
# MSSubClass       1459 non-null int64
# MSZoning         1455 non-null object
# LotFrontage      1232 non-null float64
# LotArea          1459 non-null int64
# Street           1459 non-null object
# Alley            107 non-null object
# LotShape         1459 non-null object
# LandContour      1459 non-null object
# Utilities        1457 non-null object
# LotConfig        1459 non-null object
# LandSlope        1459 non-null object
# Neighborhood     1459 non-null object
# Condition1       1459 non-null object
# Condition2       1459 non-null object
# BldgType         1459 non-null object
# HouseStyle       1459 non-null object
# OverallQual      1459 non-null int64
# OverallCond      1459 non-null int64
# YearBuilt        1459 non-null int64
# YearRemodAdd     1459 non-null int64
# RoofStyle        1459 non-null object
# ...

# %%
df_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities      ...       ScreenPorch PoolArea PoolQC  Fence  \
# 0         Lvl    AllPub      ...               120        0    NaN  MnPrv
# 1         Lvl    AllPub      ...                 0        0    NaN    NaN
# 2         Lvl    AllPub      ...                 0        0    NaN  MnPrv
# 3         Lvl    AllPub      ...                 0        0    NaN    NaN
# 4         HLS    AllPub      ...               144        0    NaN    NaN
#
#   MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
df_test_new = df_test.drop(['Alley', 'PoolQC', 'Fence', 'MiscFeature', 'FireplaceQu', 'Id'], axis=1)

# %%
df_test_new.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0          20       RH         80.0    11622   Pave      Reg         Lvl
# 1          20       RL         81.0    14267   Pave      IR1         Lvl
# 2          60       RL         74.0    13830   Pave      IR1         Lvl
# 3          60       RL         78.0     9978   Pave      IR1         Lvl
# 4         120       RL         43.0     5005   Pave      IR1         HLS
#
#   Utilities LotConfig LandSlope      ...      OpenPorchSF EnclosedPorch  \
# 0    AllPub    Inside       Gtl      ...                0             0
# 1    AllPub    Corner       Gtl      ...               36             0
# 2    AllPub    Inside       Gtl      ...               34             0
# 3    AllPub    Inside       Gtl      ...               36             0
# 4    AllPub    Inside       Gtl      ...               82             0
#
#   3SsnPorch ScreenPorch PoolArea  MiscVal  MoSold  YrSold  SaleType  \
# ...

# %%
df_test_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 74 columns):
# MSSubClass       1459 non-null int64
# MSZoning         1455 non-null object
# LotFrontage      1232 non-null float64
# LotArea          1459 non-null int64
# Street           1459 non-null object
# LotShape         1459 non-null object
# LandContour      1459 non-null object
# Utilities        1457 non-null object
# LotConfig        1459 non-null object
# LandSlope        1459 non-null object
# Neighborhood     1459 non-null object
# Condition1       1459 non-null object
# Condition2       1459 non-null object
# BldgType         1459 non-null object
# HouseStyle       1459 non-null object
# OverallQual      1459 non-null int64
# OverallCond      1459 non-null int64
# YearBuilt        1459 non-null int64
# YearRemodAdd     1459 non-null int64
# RoofStyle        1459 non-null object
# RoofMatl         1459 non-null object
# Exterior1st      1458 non-null object
# ...

# %%
df_test_new2 = df_test_new.dropna()

# %%
df_test_new2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1108 entries, 0 to 1458
# Data columns (total 74 columns):
# MSSubClass       1108 non-null int64
# MSZoning         1108 non-null object
# LotFrontage      1108 non-null float64
# LotArea          1108 non-null int64
# Street           1108 non-null object
# LotShape         1108 non-null object
# LandContour      1108 non-null object
# Utilities        1108 non-null object
# LotConfig        1108 non-null object
# LandSlope        1108 non-null object
# Neighborhood     1108 non-null object
# Condition1       1108 non-null object
# Condition2       1108 non-null object
# BldgType         1108 non-null object
# HouseStyle       1108 non-null object
# OverallQual      1108 non-null int64
# OverallCond      1108 non-null int64
# YearBuilt        1108 non-null int64
# YearRemodAdd     1108 non-null int64
# RoofStyle        1108 non-null object
# RoofMatl         1108 non-null object
# Exterior1st      1108 non-null object
# ...

# %%
cols = df_test_new2.select_dtypes(include='object').columns.tolist()
ohe = ce.OneHotEncoder(cols=cols,handle_unknown='impute', drop_invariant=False, use_cat_names=True)
type(cols)
# Out:
# list

# %%
ohe.fit(df_test_new2)
X_test = ohe.transform(df_test_new2)
X_test.head()
# Out:
#    MSSubClass  MSZoning_RH  MSZoning_RL  MSZoning_RM  MSZoning_FV  \
# 0          20            1            0            0            0
# 1          20            0            1            0            0
# 2          60            0            1            0            0
# 3          60            0            1            0            0
# 4         120            0            1            0            0
#
#    MSZoning_C (all)  LotFrontage  LotArea  Street_Pave  Street_Grvl  \
# 0                 0         80.0    11622            1            0
# 1                 0         81.0    14267            1            0
# 2                 0         74.0    13830            1            0
# 3                 0         78.0     9978            1            0
# 4                 0         43.0     5005            1            0
#
#            ...            SaleType_Oth  SaleType_ConLw  SaleType_ConLI  \
# 0          ...                       0               0               0
# ...

# %%
X_train.columns.isin(X_test.columns)
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#        False,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True, False,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True, False,  True,  True, False, False,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True, False,
#        False, False,  True,  True,  True,  True,  True,  True,  True,
# ...

# %%
X_test.columns.isin(X_train.columns)
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True, False,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
# ...

# %%
y_train = df_new2.iloc[:, -1]
X_train = df_new2.iloc[:, :-1]
X_train['label'] = 1

# %%
X_train.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0          60       RL         65.0     8450   Pave      Reg         Lvl
# 1          20       RL         80.0     9600   Pave      Reg         Lvl
# 2          60       RL         68.0    11250   Pave      IR1         Lvl
# 3          70       RL         60.0     9550   Pave      IR1         Lvl
# 4          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope  ...  EnclosedPorch 3SsnPorch ScreenPorch  \
# 0    AllPub    Inside       Gtl  ...              0         0           0
# 1    AllPub       FR2       Gtl  ...              0         0           0
# 2    AllPub    Inside       Gtl  ...              0         0           0
# 3    AllPub    Corner       Gtl  ...            272         0           0
# 4    AllPub       FR2       Gtl  ...              0         0           0
#
#   PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition label
# ...

# %%
X_test = df_test_new.fillna(df_test_new.median())
X_test.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0          20       RH         80.0    11622   Pave      Reg         Lvl
# 1          20       RL         81.0    14267   Pave      IR1         Lvl
# 2          60       RL         74.0    13830   Pave      IR1         Lvl
# 3          60       RL         78.0     9978   Pave      IR1         Lvl
# 4         120       RL         43.0     5005   Pave      IR1         HLS
#
#   Utilities LotConfig LandSlope      ...      OpenPorchSF EnclosedPorch  \
# 0    AllPub    Inside       Gtl      ...                0             0
# 1    AllPub    Corner       Gtl      ...               36             0
# 2    AllPub    Inside       Gtl      ...               34             0
# 3    AllPub    Inside       Gtl      ...               36             0
# 4    AllPub    Inside       Gtl      ...               82             0
#
#   3SsnPorch ScreenPorch PoolArea  MiscVal  MoSold  YrSold  SaleType  \
# ...

# %%
X_test['label'] = 2
X_test.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0          20       RH         80.0    11622   Pave      Reg         Lvl
# 1          20       RL         81.0    14267   Pave      IR1         Lvl
# 2          60       RL         74.0    13830   Pave      IR1         Lvl
# 3          60       RL         78.0     9978   Pave      IR1         Lvl
# 4         120       RL         43.0     5005   Pave      IR1         HLS
#
#   Utilities LotConfig LandSlope  ...  EnclosedPorch 3SsnPorch ScreenPorch  \
# 0    AllPub    Inside       Gtl  ...              0         0         120
# 1    AllPub    Corner       Gtl  ...              0         0           0
# 2    AllPub    Inside       Gtl  ...              0         0           0
# 3    AllPub    Inside       Gtl  ...              0         0           0
# 4    AllPub    Inside       Gtl  ...              0         0         144
#
#   PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition label
# ...

# %%
X = pd.concat([X_train, X_test])
X.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0          60       RL         65.0     8450   Pave      Reg         Lvl
# 1          20       RL         80.0     9600   Pave      Reg         Lvl
# 2          60       RL         68.0    11250   Pave      IR1         Lvl
# 3          70       RL         60.0     9550   Pave      IR1         Lvl
# 4          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope  ...  EnclosedPorch 3SsnPorch ScreenPorch  \
# 0    AllPub    Inside       Gtl  ...              0         0           0
# 1    AllPub       FR2       Gtl  ...              0         0           0
# 2    AllPub    Inside       Gtl  ...              0         0           0
# 3    AllPub    Corner       Gtl  ...            272         0           0
# 4    AllPub       FR2       Gtl  ...              0         0           0
#
#   PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition label
# ...

# %%
cols = X.select_dtypes(include='object').columns.tolist()
ohe = ce.OneHotEncoder(cols=cols,handle_unknown='impute', drop_invariant=False, use_cat_names=True)
ohe.fit(X)
X = ohe.transform(X)
X.head()
# Out:
#    MSSubClass  MSZoning_RL  MSZoning_RM  MSZoning_C (all)  MSZoning_FV  \
# 0          60            1            0                 0            0
# 1          20            1            0                 0            0
# 2          60            1            0                 0            0
# 3          70            1            0                 0            0
# 4          60            1            0                 0            0
#
#    MSZoning_RH  MSZoning_nan  LotFrontage  LotArea  Street_Pave  ...    \
# 0            0             0         65.0     8450            1  ...
# 1            0             0         80.0     9600            1  ...
# 2            0             0         68.0    11250            1  ...
# 3            0             0         60.0     9550            1  ...
# 4            0             0         84.0    14260            1  ...
#
#    SaleType_ConLD  SaleType_Oth  SaleType_nan  SaleCondition_Normal  \
# ...

# %%
print(X_train.shape)
print(X_test.shape)
print(X.shape)
# Out:
# (1094, 75)
# (1459, 75)
# (2553, 283)

# %%
X_train = X.query('label == 1')
X_test = X.query('label == 2')

# %%
print(X_train.shape)
print(X_test.shape)
print(X.shape)
# Out:
# (1094, 283)
# (1459, 283)
# (2553, 283)

# %%
X_train.drop(['label'], axis=1, inplace=True)
X_test.drop(['label'], axis=1, inplace=True)
# Out:
# C:\Users\Toshiya_2\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Toshiya_2\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (1094, 282)
# (1459, 282)

# %%
# feature importance using random forest
y_train = df_new2.iloc[:, -1]
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators=80, max_features='auto')
rf.fit(X_train, y_train)
print('Training done using Random Forest')

ranking = np.argsort(-rf.feature_importances_)
f, ax = plt.subplots(figsize=(11, 9))
sns.barplot(x=rf.feature_importances_[ranking], y=X_train.columns.values[ranking], orient='h')
ax.set_xlabel("feature importance")
plt.tight_layout()
plt.show()
# Out:
# Training done using Random Forest

# %%
# use the top 30 features only
X_train = X_train.iloc[:,ranking[:30]]
X_test = X_test.iloc[:,ranking[:30]]

# %%
# # outlier deletion
# Xmat = X_train
# Xmat['SalePrice'] = y_train
# Xmat = Xmat.drop(Xmat[(Xmat['TotalSF']>5) & (Xmat['SalePrice']<12.5)].index)
# Xmat = Xmat.drop(Xmat[(Xmat['GrLivArea']>5) & (Xmat['SalePrice']<13)].index)

# # recover
# y_train = Xmat['SalePrice']
# X_train = Xmat.drop(['SalePrice'], axis=1)

# %%
# XGBoost
import xgboost as xgb
from sklearn.model_selection import GridSearchCV

print("Parameter optimization")
xgb_model = xgb.XGBRegressor()
reg_xgb = GridSearchCV(xgb_model,
                   {'max_depth': [2,4,6],
                    'n_estimators': [50,100,200]}, verbose=1)
reg_xgb.fit(X_train, y_train)
# Out:
# Parameter optimization
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [01:04:00] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:04:00] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# C:\Users\Toshiya_2\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [01:04:00] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ...

# %%
y_pred = reg_xgb.predict(X_test)

# %%
test_id = df_test['Id']

# %%
# submission
submission = pd.DataFrame({
    "Id": test_id,
    "SalePrice": y_pred
})
submission.to_csv('houseprice.csv', index=False)
